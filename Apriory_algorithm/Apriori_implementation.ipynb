# %%
import pandas as pd 
import numpy as np 
from itertools import combinations
from itertools import permutations
import itertools

# %%
class Apriori:
    def __init__(self, df):
        self.transactions = []
        self.list_of_frequent_items = []
        for purchase in df.values:
            series = pd.Series(purchase)
            series = series.dropna()
            result = series.tolist()
            self.transactions.append(result)
        all_items = np.array(df.values).ravel()
        self.unique_items_in_dataset = (pd.Series(pd.unique(all_items)).dropna()).tolist()
        
    def calculate_support(self, itemset):
        itemset_count = 0
        total_transactions = len(self.transactions)

        for transaction in self.transactions:
            if all(item in transaction for item in itemset):
                itemset_count += 1

        support = itemset_count / total_transactions
        return support

    def calculate_confidence(self,Y, Z):
        support_YZ = self.calculate_support(Y + Z)
        support_Y = self.calculate_support(Y)

        confidence = support_YZ / support_Y
        return confidence
    
    def calculate_lift(self,Y, Z):
        confidence = self.calculate_confidence(Y, Z)
        support_Z = self.calculate_support(Z)

        lift = confidence / support_Z
        return lift
    
    def get_all_combs(self,fris, k):
        combinations_list = [list(x) for x in (combinations(fris, k))]
        return combinations_list
    
    def frequent_itemsets(self,combinations):
        frequent_items = []
        for item in combinations:
            if self.calculate_support(item) >= self.minimum_support:
                frequent_items.append(item)
        return frequent_items
    
    def get_and_prune(self,minimum_support):
        self.minimum_support = minimum_support
        k = 1
        fris = self.unique_items_in_dataset
        all_frequents = []
        while True:
            fris = self.frequent_itemsets(self.get_all_combs(fris, k))
            sfris = list(pd.unique(np.array(fris).flatten()))
            all_frequents.append(fris)
            fris = sfris
            k += 1
            if len(fris) == 0 :
                break
        self.all_frequents = all_frequents
        return all_frequents
    
    def generate_association_rules(self, min_confidence, min_lift):
        association_rules = []
        high_lifts_rules = []
        for itemset_list in self.all_frequents:
            for itemset in itemset_list:
                if len(itemset) > 1:
                    itemset_permutations = list(permutations(itemset, len(itemset)))

                    for permutation in itemset_permutations:
                        for i in range(1, len(permutation)):
                            antecedent = permutation[:i]
                            consequent = permutation[i:]

                            confidence = self.calculate_confidence(antecedent, consequent)
                            lift = self.calculate_lift(antecedent, consequent)
                        

                            if confidence >= min_confidence:
                                association_rules.append((antecedent, consequent, confidence, lift ))
                                if lift >= min_lift:
                                    high_lifts_rules.append((antecedent, consequent, confidence, lift))

        self.assosiation_rules = association_rules
        self.high_lifts_rules = high_lifts_rules                      
        return association_rules , high_lifts_rules
    
    def print_assosiation_rules(self):
        print("assossiation rules : ")
        for rule in self.assosiation_rules:
            antecedent = rule[0]
            consequent = rule[1]
            confidence = round(rule[2], 3)
            lift = round(rule[3], 3)
            print(str(antecedent)+" ---> " + str(consequent) + "|| confidence = " + str(confidence)+"  &  lift = " + str(lift))
        print("-"*200)
        print("strong assossiation_rules : ")
        for rule in self.high_lifts_rules:
            antecedent = rule[0]
            consequent = rule[1]
            confidence = round(rule[2], 3)
            lift = round(rule[3], 3)
            print(str(antecedent)+" ---> " + str(consequent) + "|| confidence = " + str(confidence)+ "  &  lift = " + str(lift))

# %%
datad = {
    "T1" : ["HotDogs", "Buns", "Ketchup"],
    "T2" : ["HotDogs", "Buns", np.nan],
    "T3" : ["HotDogs", "Coke", "Chips"],
    "T4" : ["Chips", "Coke", np.nan],
    "T5" : ["Chips", "Ketchup", np.nan],
    "T6" : ["HotDogs", "Coke", "Chips"]
}
data = pd.DataFrame(datad).T
data
# Out:
#           0        1        2
# T1  HotDogs     Buns  Ketchup
# T2  HotDogs     Buns      NaN
# T3  HotDogs     Coke    Chips
# T4    Chips     Coke      NaN
# T5    Chips  Ketchup      NaN
# T6  HotDogs     Coke    Chips

# %%
a = Apriori(data)

# %%
frequent_items = a.get_and_prune(minimum_support=1/3)

# %%
a.generate_association_rules(0.6, 2)
# Out:
# ([(('Buns',), ('HotDogs',), 1.0, 1.5),
#   (('Coke',), ('HotDogs',), 0.6666666666666666, 1.0),
#   (('Coke',), ('Chips',), 1.0, 1.5),
#   (('Chips',), ('Coke',), 0.75, 1.5),
#   (('HotDogs', 'Coke'), ('Chips',), 1.0, 1.5),
#   (('HotDogs', 'Chips'), ('Coke',), 1.0, 2.0),
#   (('Coke',), ('HotDogs', 'Chips'), 0.6666666666666666, 2.0),
#   (('Coke', 'HotDogs'), ('Chips',), 1.0, 1.5),
#   (('Coke',), ('Chips', 'HotDogs'), 0.6666666666666666, 2.0),
#   (('Coke', 'Chips'), ('HotDogs',), 0.6666666666666666, 1.0),
#   (('Chips', 'HotDogs'), ('Coke',), 1.0, 2.0),
#   (('Chips', 'Coke'), ('HotDogs',), 0.6666666666666666, 1.0)],
#  [(('HotDogs', 'Chips'), ('Coke',), 1.0, 2.0),
#   (('Coke',), ('HotDogs', 'Chips'), 0.6666666666666666, 2.0),
#   (('Coke',), ('Chips', 'HotDogs'), 0.6666666666666666, 2.0),
#   (('Chips', 'HotDogs'), ('Coke',), 1.0, 2.0)])

# %%
a.print_assosiation_rules()
# Out:
# assossiation rules :
# ('Buns',) ---> ('HotDogs',)|| confidence = 1.0  &  lift = 1.5
# ('Coke',) ---> ('HotDogs',)|| confidence = 0.667  &  lift = 1.0
# ('Coke',) ---> ('Chips',)|| confidence = 1.0  &  lift = 1.5
# ('Chips',) ---> ('Coke',)|| confidence = 0.75  &  lift = 1.5
# ('HotDogs', 'Coke') ---> ('Chips',)|| confidence = 1.0  &  lift = 1.5
# ('HotDogs', 'Chips') ---> ('Coke',)|| confidence = 1.0  &  lift = 2.0
# ('Coke',) ---> ('HotDogs', 'Chips')|| confidence = 0.667  &  lift = 2.0
# ('Coke', 'HotDogs') ---> ('Chips',)|| confidence = 1.0  &  lift = 1.5
# ('Coke',) ---> ('Chips', 'HotDogs')|| confidence = 0.667  &  lift = 2.0
# ('Coke', 'Chips') ---> ('HotDogs',)|| confidence = 0.667  &  lift = 1.0
# ('Chips', 'HotDogs') ---> ('Coke',)|| confidence = 1.0  &  lift = 2.0
# ('Chips', 'Coke') ---> ('HotDogs',)|| confidence = 0.667  &  lift = 1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# strong assossiation_rules :
# ('HotDogs', 'Chips') ---> ('Coke',)|| confidence = 1.0  &  lift = 2.0
# ('Coke',) ---> ('HotDogs', 'Chips')|| confidence = 0.667  &  lift = 2.0
# ('Coke',) ---> ('Chips', 'HotDogs')|| confidence = 0.667  &  lift = 2.0
# ('Chips', 'HotDogs') ---> ('Coke',)|| confidence = 1.0  &  lift = 2.0

# %%
df = pd.DataFrame(pd.read_csv("./Market_Basket_Optimisation.csv", header=None))

# %%
ap = Apriori(df)

# %%
ap.get_and_prune(0.008)
ap.generate_association_rules(0.2, 3)
ap.print_assosiation_rules()
# Out:
# assossiation rules :
# ('shrimp',) ---> ('mineral water',)|| confidence = 0.33  &  lift = 1.385
# ('shrimp',) ---> ('milk',)|| confidence = 0.246  &  lift = 1.9
# ('shrimp',) ---> ('frozen vegetables',)|| confidence = 0.233  &  lift = 2.447
# ('shrimp',) ---> ('spaghetti',)|| confidence = 0.297  &  lift = 1.704
# ('shrimp',) ---> ('chocolate',)|| confidence = 0.252  &  lift = 1.537
# ('avocado',) ---> ('mineral water',)|| confidence = 0.348  &  lift = 1.46
# ('cottage cheese',) ---> ('mineral water',)|| confidence = 0.301  &  lift = 1.264
# ('tomato juice',) ---> ('mineral water',)|| confidence = 0.316  &  lift = 1.325
# ('low fat yogurt',) ---> ('mineral water',)|| confidence = 0.314  &  lift = 1.316
# ('low fat yogurt',) ---> ('eggs',)|| confidence = 0.22  &  lift = 1.221
# ('green tea',) ---> ('mineral water',)|| confidence = 0.235  &  lift = 0.986
# ('burgers',) ---> ('green tea',)|| confidence = 0.2  &  lift = 1.516
# ('green tea',) ---> ('french fries',)|| confidence = 0.216  &  lift = 1.263
# ('green tea',) ---> ('spaghetti',)|| confidence = 0.201  &  lift = 1.153
# ('honey',) ---> ('mineral water',)|| confidence = 0.317  &  lift = 1.332
# ('honey',) ---> ('spaghetti',)|| confidence = 0.25  &  lift = 1.436
# ('salmon',) ---> ('mineral water',)|| confidence = 0.401  &  lift = 1.683
# ('frozen smoothie',) ---> ('mineral water',)|| confidence = 0.32  &  lift = 1.342
# ('olive oil',) ---> ('mineral water',)|| confidence = 0.419  &  lift = 1.758
# ('burgers',) ---> ('mineral water',)|| confidence = 0.28  &  lift = 1.174
# ('mineral water',) ---> ('eggs',)|| confidence = 0.214  &  lift = 1.189
# ('eggs',) ---> ('mineral water',)|| confidence = 0.283  &  lift = 1.189
# ('turkey',) ---> ('mineral water',)|| confidence = 0.307  &  lift = 1.288
# ('mineral water',) ---> ('milk',)|| confidence = 0.201  &  lift = 1.554
# ('milk',) ---> ('mineral water',)|| confidence = 0.37  &  lift = 1.554
# ('whole wheat rice',) ---> ('mineral water',)|| confidence = 0.344  &  lift = 1.443
# ('whole wheat pasta',) ---> ('mineral water',)|| confidence = 0.326  &  lift = 1.367
# ('soup',) ---> ('mineral water',)|| confidence = 0.456  &  lift = 1.915
# ('frozen vegetables',) ---> ('mineral water',)|| confidence = 0.375  &  lift = 1.572
# ('mineral water',) ---> ('spaghetti',)|| confidence = 0.251  &  lift = 1.439
# ('spaghetti',) ---> ('mineral water',)|| confidence = 0.343  &  lift = 1.439
# ('cooking oil',) ---> ('mineral water',)|| confidence = 0.394  &  lift = 1.654
# ('mineral water',) ---> ('chocolate',)|| confidence = 0.221  &  lift = 1.348
# ('chocolate',) ---> ('mineral water',)|| confidence = 0.321  &  lift = 1.348
# ('chicken',) ---> ('mineral water',)|| confidence = 0.38  &  lift = 1.594
# ('fresh tuna',) ---> ('mineral water',)|| confidence = 0.395  &  lift = 1.658
# ('tomatoes',) ---> ('mineral water',)|| confidence = 0.357  &  lift = 1.497
# ('red wine',) ---> ('mineral water',)|| confidence = 0.389  &  lift = 1.63
# ('pepper',) ---> ('mineral water',)|| confidence = 0.312  &  lift = 1.307
# ('ham',) ---> ('mineral water',)|| confidence = 0.347  &  lift = 1.455
# ('pancakes',) ---> ('mineral water',)|| confidence = 0.355  &  lift = 1.489
# ('grated cheese',) ---> ('mineral water',)|| confidence = 0.333  &  lift = 1.398
# ('fresh bread',) ---> ('mineral water',)|| confidence = 0.31  &  lift = 1.299
# ('ground beef',) ---> ('mineral water',)|| confidence = 0.417  &  lift = 1.748
# ('escalope',) ---> ('mineral water',)|| confidence = 0.215  &  lift = 0.902
# ('herb & pepper',) ---> ('mineral water',)|| confidence = 0.345  &  lift = 1.447
# ('cake',) ---> ('mineral water',)|| confidence = 0.339  &  lift = 1.421
# ('hot dogs',) ---> ('mineral water',)|| confidence = 0.284  &  lift = 1.191
# ('brownies',) ---> ('mineral water',)|| confidence = 0.285  &  lift = 1.194
# ('cereals',) ---> ('mineral water',)|| confidence = 0.399  &  lift = 1.674
# ('french wine',) ---> ('mineral water',)|| confidence = 0.367  &  lift = 1.539
# ('salmon',) ---> ('milk',)|| confidence = 0.229  &  lift = 1.766
# ('salmon',) ---> ('spaghetti',)|| confidence = 0.317  &  lift = 1.818
# ('salmon',) ---> ('chocolate',)|| confidence = 0.251  &  lift = 1.531
# ('salmon',) ---> ('ground beef',)|| confidence = 0.21  &  lift = 2.138
# ('frozen smoothie',) ---> ('milk',)|| confidence = 0.225  &  lift = 1.738
# ('frozen smoothie',) ---> ('french fries',)|| confidence = 0.229  &  lift = 1.343
# ('frozen smoothie',) ---> ('spaghetti',)|| confidence = 0.246  &  lift = 1.415
# ('frozen smoothie',) ---> ('chocolate',)|| confidence = 0.236  &  lift = 1.439
# ('olive oil',) ---> ('milk',)|| confidence = 0.259  &  lift = 2.0
# ('olive oil',) ---> ('spaghetti',)|| confidence = 0.348  &  lift = 2.0
# ('olive oil',) ---> ('chocolate',)|| confidence = 0.249  &  lift = 1.52
# ('olive oil',) ---> ('ground beef',)|| confidence = 0.215  &  lift = 2.184
# ('burgers',) ---> ('eggs',)|| confidence = 0.33  &  lift = 1.838
# ('burgers',) ---> ('milk',)|| confidence = 0.205  &  lift = 1.581
# ('burgers',) ---> ('french fries',)|| confidence = 0.252  &  lift = 1.476
# ('burgers',) ---> ('spaghetti',)|| confidence = 0.246  &  lift = 1.414
# ('turkey',) ---> ('eggs',)|| confidence = 0.311  &  lift = 1.732
# ('milk',) ---> ('eggs',)|| confidence = 0.238  &  lift = 1.322
# ('eggs',) ---> ('french fries',)|| confidence = 0.203  &  lift = 1.185
# ('french fries',) ---> ('eggs',)|| confidence = 0.213  &  lift = 1.185
# ('frozen vegetables',) ---> ('eggs',)|| confidence = 0.228  &  lift = 1.269
# ('eggs',) ---> ('spaghetti',)|| confidence = 0.203  &  lift = 1.167
# ('spaghetti',) ---> ('eggs',)|| confidence = 0.21  &  lift = 1.167
# ('cooking oil',) ---> ('eggs',)|| confidence = 0.23  &  lift = 1.279
# ('chocolate',) ---> ('eggs',)|| confidence = 0.203  &  lift = 1.127
# ('chicken',) ---> ('eggs',)|| confidence = 0.24  &  lift = 1.335
# ('pancakes',) ---> ('eggs',)|| confidence = 0.229  &  lift = 1.272
# ('fresh bread',) ---> ('eggs',)|| confidence = 0.201  &  lift = 1.12
# ('ground beef',) ---> ('eggs',)|| confidence = 0.204  &  lift = 1.133
# ('herb & pepper',) ---> ('eggs',)|| confidence = 0.253  &  lift = 1.41
# ('cake',) ---> ('eggs',)|| confidence = 0.235  &  lift = 1.309
# ('turkey',) ---> ('spaghetti',)|| confidence = 0.264  &  lift = 1.519
# ('whole wheat rice',) ---> ('milk',)|| confidence = 0.203  &  lift = 1.565
# ('whole wheat pasta',) ---> ('milk',)|| confidence = 0.335  &  lift = 2.584
# ('soup',) ---> ('milk',)|| confidence = 0.301  &  lift = 2.321
# ('frozen vegetables',) ---> ('milk',)|| confidence = 0.248  &  lift = 1.91
# ('milk',) ---> ('spaghetti',)|| confidence = 0.274  &  lift = 1.572
# ('spaghetti',) ---> ('milk',)|| confidence = 0.204  &  lift = 1.572
# ('cooking oil',) ---> ('milk',)|| confidence = 0.225  &  lift = 1.733
# ('milk',) ---> ('chocolate',)|| confidence = 0.248  &  lift = 1.513
# ('chicken',) ---> ('milk',)|| confidence = 0.247  &  lift = 1.904
# ('tomatoes',) ---> ('milk',)|| confidence = 0.205  &  lift = 1.58
# ('fresh bread',) ---> ('milk',)|| confidence = 0.214  &  lift = 1.649
# ('ground beef',) ---> ('milk',)|| confidence = 0.224  &  lift = 1.728
# ('whole wheat rice',) ---> ('spaghetti',)|| confidence = 0.241  &  lift = 1.387
# ('whole wheat rice',) ---> ('chocolate',)|| confidence = 0.205  &  lift = 1.251
# ('whole wheat pasta',) ---> ('spaghetti',)|| confidence = 0.299  &  lift = 1.715
# ('french fries',) ---> ('chocolate',)|| confidence = 0.201  &  lift = 1.228
# ('chocolate',) ---> ('french fries',)|| confidence = 0.21  &  lift = 1.228
# ('pancakes',) ---> ('french fries',)|| confidence = 0.212  &  lift = 1.239
# ('escalope',) ---> ('french fries',)|| confidence = 0.207  &  lift = 1.21
# ('cake',) ---> ('french fries',)|| confidence = 0.22  &  lift = 1.29
# ('soup',) ---> ('spaghetti',)|| confidence = 0.282  &  lift = 1.622
# ('soup',) ---> ('chocolate',)|| confidence = 0.201  &  lift = 1.224
# ('frozen vegetables',) ---> ('spaghetti',)|| confidence = 0.292  &  lift = 1.679
# ('frozen vegetables',) ---> ('chocolate',)|| confidence = 0.241  &  lift = 1.468
# ('tomatoes',) ---> ('frozen vegetables',)|| confidence = 0.236  &  lift = 2.474
# ('cooking oil',) ---> ('spaghetti',)|| confidence = 0.311  &  lift = 1.785
# ('spaghetti',) ---> ('chocolate',)|| confidence = 0.225  &  lift = 1.374
# ('chocolate',) ---> ('spaghetti',)|| confidence = 0.239  &  lift = 1.374
# ('chicken',) ---> ('spaghetti',)|| confidence = 0.287  &  lift = 1.646
# ('tomatoes',) ---> ('spaghetti',)|| confidence = 0.306  &  lift = 1.758
# ('red wine',) ---> ('spaghetti',)|| confidence = 0.365  &  lift = 2.096
# ('pepper',) ---> ('spaghetti',)|| confidence = 0.372  &  lift = 2.136
# ('ham',) ---> ('spaghetti',)|| confidence = 0.347  &  lift = 1.991
# ('pancakes',) ---> ('spaghetti',)|| confidence = 0.265  &  lift = 1.522
# ('grated cheese',) ---> ('spaghetti',)|| confidence = 0.316  &  lift = 1.812
# ('fresh bread',) ---> ('spaghetti',)|| confidence = 0.211  &  lift = 1.209
# ('spaghetti',) ---> ('ground beef',)|| confidence = 0.225  &  lift = 2.291
# ('ground beef',) ---> ('spaghetti',)|| confidence = 0.399  &  lift = 2.291
# ('herb & pepper',) ---> ('spaghetti',)|| confidence = 0.329  &  lift = 1.889
# ('cake',) ---> ('spaghetti',)|| confidence = 0.224  &  lift = 1.285
# ('hot dogs',) ---> ('spaghetti',)|| confidence = 0.267  &  lift = 1.536
# ('cooking oil',) ---> ('chocolate',)|| confidence = 0.266  &  lift = 1.625
# ('champagne',) ---> ('chocolate',)|| confidence = 0.248  &  lift = 1.513
# ('chicken',) ---> ('chocolate',)|| confidence = 0.244  &  lift = 1.492
# ('tomatoes',) ---> ('chocolate',)|| confidence = 0.205  &  lift = 1.249
# ('pancakes',) ---> ('chocolate',)|| confidence = 0.209  &  lift = 1.275
# ('grated cheese',) ---> ('chocolate',)|| confidence = 0.209  &  lift = 1.273
# ('fresh bread',) ---> ('chocolate',)|| confidence = 0.22  &  lift = 1.342
# ('ground beef',) ---> ('chocolate',)|| confidence = 0.235  &  lift = 1.433
# ('escalope',) ---> ('chocolate',)|| confidence = 0.222  &  lift = 1.354
# ('butter',) ---> ('chocolate',)|| confidence = 0.274  &  lift = 1.674
# ('grated cheese',) ---> ('ground beef',)|| confidence = 0.216  &  lift = 2.201
# ('herb & pepper',) ---> ('ground beef',)|| confidence = 0.323  &  lift = 3.292
# ('shrimp', 'mineral water') ---> ('spaghetti',)|| confidence = 0.362  &  lift = 2.077
# ('shrimp', 'spaghetti') ---> ('mineral water',)|| confidence = 0.403  &  lift = 1.689
# ('mineral water', 'shrimp') ---> ('spaghetti',)|| confidence = 0.362  &  lift = 2.077
# ('spaghetti', 'shrimp') ---> ('mineral water',)|| confidence = 0.403  &  lift = 1.689
# ('green tea', 'mineral water') ---> ('spaghetti',)|| confidence = 0.266  &  lift = 1.528
# ('green tea', 'spaghetti') ---> ('mineral water',)|| confidence = 0.312  &  lift = 1.307
# ('mineral water', 'green tea') ---> ('spaghetti',)|| confidence = 0.266  &  lift = 1.528
# ('spaghetti', 'green tea') ---> ('mineral water',)|| confidence = 0.312  &  lift = 1.307
# ('mineral water', 'olive oil') ---> ('milk',)|| confidence = 0.309  &  lift = 2.386
# ('olive oil', 'mineral water') ---> ('milk',)|| confidence = 0.309  &  lift = 2.386
# ('olive oil', 'milk') ---> ('mineral water',)|| confidence = 0.5  &  lift = 2.098
# ('milk', 'olive oil') ---> ('mineral water',)|| confidence = 0.5  &  lift = 2.098
# ('mineral water', 'olive oil') ---> ('spaghetti',)|| confidence = 0.372  &  lift = 2.136
# ('olive oil', 'mineral water') ---> ('spaghetti',)|| confidence = 0.372  &  lift = 2.136
# ('olive oil', 'spaghetti') ---> ('mineral water',)|| confidence = 0.448  &  lift = 1.878
# ('spaghetti', 'olive oil') ---> ('mineral water',)|| confidence = 0.448  &  lift = 1.878
# ('mineral water', 'olive oil') ---> ('chocolate',)|| confidence = 0.3  &  lift = 1.828
# ('olive oil', 'mineral water') ---> ('chocolate',)|| confidence = 0.3  &  lift = 1.828
# ('olive oil', 'chocolate') ---> ('mineral water',)|| confidence = 0.504  &  lift = 2.115
# ('chocolate', 'olive oil') ---> ('mineral water',)|| confidence = 0.504  &  lift = 2.115
# ('mineral water', 'eggs') ---> ('milk',)|| confidence = 0.257  &  lift = 1.98
# ('mineral water', 'milk') ---> ('eggs',)|| confidence = 0.272  &  lift = 1.515
# ('eggs', 'mineral water') ---> ('milk',)|| confidence = 0.257  &  lift = 1.98
# ('eggs', 'milk') ---> ('mineral water',)|| confidence = 0.424  &  lift = 1.78
# ('milk', 'mineral water') ---> ('eggs',)|| confidence = 0.272  &  lift = 1.515
# ('milk', 'eggs') ---> ('mineral water',)|| confidence = 0.424  &  lift = 1.78
# ('mineral water', 'frozen vegetables') ---> ('eggs',)|| confidence = 0.254  &  lift = 1.412
# ('eggs', 'frozen vegetables') ---> ('mineral water',)|| confidence = 0.417  &  lift = 1.75
# ('frozen vegetables', 'mineral water') ---> ('eggs',)|| confidence = 0.254  &  lift = 1.412
# ('frozen vegetables', 'eggs') ---> ('mineral water',)|| confidence = 0.417  &  lift = 1.75
# ('mineral water', 'eggs') ---> ('spaghetti',)|| confidence = 0.28  &  lift = 1.609
# ('mineral water', 'spaghetti') ---> ('eggs',)|| confidence = 0.239  &  lift = 1.329
# ('eggs', 'mineral water') ---> ('spaghetti',)|| confidence = 0.28  &  lift = 1.609
# ('eggs', 'spaghetti') ---> ('mineral water',)|| confidence = 0.391  &  lift = 1.638
# ('spaghetti', 'mineral water') ---> ('eggs',)|| confidence = 0.239  &  lift = 1.329
# ('spaghetti', 'eggs') ---> ('mineral water',)|| confidence = 0.391  &  lift = 1.638
# ('mineral water', 'eggs') ---> ('chocolate',)|| confidence = 0.264  &  lift = 1.614
# ('mineral water', 'chocolate') ---> ('eggs',)|| confidence = 0.256  &  lift = 1.423
# ('eggs', 'mineral water') ---> ('chocolate',)|| confidence = 0.264  &  lift = 1.614
# ('eggs', 'chocolate') ---> ('mineral water',)|| confidence = 0.406  &  lift = 1.702
# ('chocolate', 'mineral water') ---> ('eggs',)|| confidence = 0.256  &  lift = 1.423
# ('chocolate', 'eggs') ---> ('mineral water',)|| confidence = 0.406  &  lift = 1.702
# ('mineral water', 'ground beef') ---> ('eggs',)|| confidence = 0.248  &  lift = 1.378
# ('eggs', 'ground beef') ---> ('mineral water',)|| confidence = 0.507  &  lift = 2.126
# ('ground beef', 'mineral water') ---> ('eggs',)|| confidence = 0.248  &  lift = 1.378
# ('ground beef', 'eggs') ---> ('mineral water',)|| confidence = 0.507  &  lift = 2.126
# ('mineral water', 'french fries') ---> ('milk',)|| confidence = 0.245  &  lift = 1.891
# ('milk', 'french fries') ---> ('mineral water',)|| confidence = 0.348  &  lift = 1.461
# ('french fries', 'mineral water') ---> ('milk',)|| confidence = 0.245  &  lift = 1.891
# ('french fries', 'milk') ---> ('mineral water',)|| confidence = 0.348  &  lift = 1.461
# ('mineral water', 'milk') ---> ('frozen vegetables',)|| confidence = 0.231  &  lift = 2.419
# ('mineral water', 'frozen vegetables') ---> ('milk',)|| confidence = 0.31  &  lift = 2.39
# ('milk', 'mineral water') ---> ('frozen vegetables',)|| confidence = 0.231  &  lift = 2.419
# ('milk', 'frozen vegetables') ---> ('mineral water',)|| confidence = 0.469  &  lift = 1.967
# ('frozen vegetables', 'mineral water') ---> ('milk',)|| confidence = 0.31  &  lift = 2.39
# ('frozen vegetables', 'milk') ---> ('mineral water',)|| confidence = 0.469  &  lift = 1.967
# ('mineral water', 'milk') ---> ('spaghetti',)|| confidence = 0.328  &  lift = 1.883
# ('mineral water', 'spaghetti') ---> ('milk',)|| confidence = 0.263  &  lift = 2.033
# ('milk', 'mineral water') ---> ('spaghetti',)|| confidence = 0.328  &  lift = 1.883
# ('milk', 'spaghetti') ---> ('mineral water',)|| confidence = 0.444  &  lift = 1.861
# ('spaghetti', 'mineral water') ---> ('milk',)|| confidence = 0.263  &  lift = 2.033
# ('spaghetti', 'milk') ---> ('mineral water',)|| confidence = 0.444  &  lift = 1.861
# ('mineral water', 'milk') ---> ('chocolate',)|| confidence = 0.292  &  lift = 1.78
# ('mineral water', 'chocolate') ---> ('milk',)|| confidence = 0.266  &  lift = 2.051
# ('milk', 'mineral water') ---> ('chocolate',)|| confidence = 0.292  &  lift = 1.78
# ('milk', 'chocolate') ---> ('mineral water',)|| confidence = 0.436  &  lift = 1.828
# ('chocolate', 'mineral water') ---> ('milk',)|| confidence = 0.266  &  lift = 2.051
# ('chocolate', 'milk') ---> ('mineral water',)|| confidence = 0.436  &  lift = 1.828
# ('mineral water', 'milk') ---> ('ground beef',)|| confidence = 0.231  &  lift = 2.347
# ('mineral water', 'ground beef') ---> ('milk',)|| confidence = 0.27  &  lift = 2.086
# ('milk', 'mineral water') ---> ('ground beef',)|| confidence = 0.231  &  lift = 2.347
# ('milk', 'ground beef') ---> ('mineral water',)|| confidence = 0.503  &  lift = 2.11
# ('ground beef', 'mineral water') ---> ('milk',)|| confidence = 0.27  &  lift = 2.086
# ('ground beef', 'milk') ---> ('mineral water',)|| confidence = 0.503  &  lift = 2.11
# ('mineral water', 'soup') ---> ('milk',)|| confidence = 0.37  &  lift = 2.855
# ('milk', 'soup') ---> ('mineral water',)|| confidence = 0.561  &  lift = 2.355
# ('soup', 'mineral water') ---> ('milk',)|| confidence = 0.37  &  lift = 2.855
# ('soup', 'milk') ---> ('mineral water',)|| confidence = 0.561  &  lift = 2.355
# ('mineral water', 'french fries') ---> ('spaghetti',)|| confidence = 0.3  &  lift = 1.725
# ('french fries', 'mineral water') ---> ('spaghetti',)|| confidence = 0.3  &  lift = 1.725
# ('french fries', 'spaghetti') ---> ('mineral water',)|| confidence = 0.367  &  lift = 1.54
# ('spaghetti', 'french fries') ---> ('mineral water',)|| confidence = 0.367  &  lift = 1.54
# ('mineral water', 'french fries') ---> ('chocolate',)|| confidence = 0.253  &  lift = 1.544
# ('french fries', 'mineral water') ---> ('chocolate',)|| confidence = 0.253  &  lift = 1.544
# ('french fries', 'chocolate') ---> ('mineral water',)|| confidence = 0.248  &  lift = 1.041
# ('chocolate', 'french fries') ---> ('mineral water',)|| confidence = 0.248  &  lift = 1.041
# ('mineral water', 'frozen vegetables') ---> ('spaghetti',)|| confidence = 0.336  &  lift = 1.929
# ('mineral water', 'spaghetti') ---> ('frozen vegetables',)|| confidence = 0.201  &  lift = 2.108
# ('frozen vegetables', 'mineral water') ---> ('spaghetti',)|| confidence = 0.336  &  lift = 1.929
# ('frozen vegetables', 'spaghetti') ---> ('mineral water',)|| confidence = 0.431  &  lift = 1.807
# ('spaghetti', 'mineral water') ---> ('frozen vegetables',)|| confidence = 0.201  &  lift = 2.108
# ('spaghetti', 'frozen vegetables') ---> ('mineral water',)|| confidence = 0.431  &  lift = 1.807
# ('mineral water', 'frozen vegetables') ---> ('chocolate',)|| confidence = 0.272  &  lift = 1.662
# ('frozen vegetables', 'mineral water') ---> ('chocolate',)|| confidence = 0.272  &  lift = 1.662
# ('frozen vegetables', 'chocolate') ---> ('mineral water',)|| confidence = 0.424  &  lift = 1.781
# ('chocolate', 'frozen vegetables') ---> ('mineral water',)|| confidence = 0.424  &  lift = 1.781
# ('mineral water', 'frozen vegetables') ---> ('ground beef',)|| confidence = 0.257  &  lift = 2.62
# ('mineral water', 'ground beef') ---> ('frozen vegetables',)|| confidence = 0.225  &  lift = 2.358
# ('frozen vegetables', 'mineral water') ---> ('ground beef',)|| confidence = 0.257  &  lift = 2.62
# ('frozen vegetables', 'ground beef') ---> ('mineral water',)|| confidence = 0.543  &  lift = 2.279
# ('ground beef', 'mineral water') ---> ('frozen vegetables',)|| confidence = 0.225  &  lift = 2.358
# ('ground beef', 'frozen vegetables') ---> ('mineral water',)|| confidence = 0.543  &  lift = 2.279
# ('mineral water', 'spaghetti') ---> ('chocolate',)|| confidence = 0.266  &  lift = 1.621
# ('mineral water', 'chocolate') ---> ('spaghetti',)|| confidence = 0.301  &  lift = 1.73
# ('spaghetti', 'mineral water') ---> ('chocolate',)|| confidence = 0.266  &  lift = 1.621
# ('spaghetti', 'chocolate') ---> ('mineral water',)|| confidence = 0.405  &  lift = 1.698
# ('chocolate', 'mineral water') ---> ('spaghetti',)|| confidence = 0.301  &  lift = 1.73
# ('chocolate', 'spaghetti') ---> ('mineral water',)|| confidence = 0.405  &  lift = 1.698
# ('mineral water', 'tomatoes') ---> ('spaghetti',)|| confidence = 0.383  &  lift = 2.197
# ('spaghetti', 'tomatoes') ---> ('mineral water',)|| confidence = 0.446  &  lift = 1.87
# ('tomatoes', 'mineral water') ---> ('spaghetti',)|| confidence = 0.383  &  lift = 2.197
# ('tomatoes', 'spaghetti') ---> ('mineral water',)|| confidence = 0.446  &  lift = 1.87
# ('mineral water', 'pancakes') ---> ('spaghetti',)|| confidence = 0.34  &  lift = 1.952
# ('spaghetti', 'pancakes') ---> ('mineral water',)|| confidence = 0.455  &  lift = 1.909
# ('pancakes', 'mineral water') ---> ('spaghetti',)|| confidence = 0.34  &  lift = 1.952
# ('pancakes', 'spaghetti') ---> ('mineral water',)|| confidence = 0.455  &  lift = 1.909
# ('mineral water', 'spaghetti') ---> ('ground beef',)|| confidence = 0.286  &  lift = 2.908
# ('mineral water', 'ground beef') ---> ('spaghetti',)|| confidence = 0.417  &  lift = 2.395
# ('spaghetti', 'mineral water') ---> ('ground beef',)|| confidence = 0.286  &  lift = 2.908
# ('spaghetti', 'ground beef') ---> ('mineral water',)|| confidence = 0.435  &  lift = 1.826
# ('ground beef', 'mineral water') ---> ('spaghetti',)|| confidence = 0.417  &  lift = 2.395
# ('ground beef', 'spaghetti') ---> ('mineral water',)|| confidence = 0.435  &  lift = 1.826
# ('mineral water', 'pancakes') ---> ('chocolate',)|| confidence = 0.277  &  lift = 1.689
# ('chocolate', 'pancakes') ---> ('mineral water',)|| confidence = 0.47  &  lift = 1.971
# ('pancakes', 'mineral water') ---> ('chocolate',)|| confidence = 0.277  &  lift = 1.689
# ('pancakes', 'chocolate') ---> ('mineral water',)|| confidence = 0.47  &  lift = 1.971
# ('mineral water', 'chocolate') ---> ('ground beef',)|| confidence = 0.208  &  lift = 2.113
# ('mineral water', 'ground beef') ---> ('chocolate',)|| confidence = 0.267  &  lift = 1.63
# ('chocolate', 'mineral water') ---> ('ground beef',)|| confidence = 0.208  &  lift = 2.113
# ('chocolate', 'ground beef') ---> ('mineral water',)|| confidence = 0.474  &  lift = 1.988
# ('ground beef', 'mineral water') ---> ('chocolate',)|| confidence = 0.267  &  lift = 1.63
# ('ground beef', 'chocolate') ---> ('mineral water',)|| confidence = 0.474  &  lift = 1.988
# ('burgers', 'eggs') ---> ('french fries',)|| confidence = 0.315  &  lift = 1.842
# ('burgers', 'french fries') ---> ('eggs',)|| confidence = 0.412  &  lift = 2.293
# ('eggs', 'burgers') ---> ('french fries',)|| confidence = 0.315  &  lift = 1.842
# ('eggs', 'french fries') ---> ('burgers',)|| confidence = 0.249  &  lift = 2.857
# ('french fries', 'burgers') ---> ('eggs',)|| confidence = 0.412  &  lift = 2.293
# ('french fries', 'eggs') ---> ('burgers',)|| confidence = 0.249  &  lift = 2.857
# ('eggs', 'milk') ---> ('spaghetti',)|| confidence = 0.29  &  lift = 1.666
# ('eggs', 'spaghetti') ---> ('milk',)|| confidence = 0.245  &  lift = 1.887
# ('milk', 'eggs') ---> ('spaghetti',)|| confidence = 0.29  &  lift = 1.666
# ('milk', 'spaghetti') ---> ('eggs',)|| confidence = 0.252  &  lift = 1.402
# ('spaghetti', 'eggs') ---> ('milk',)|| confidence = 0.245  &  lift = 1.887
# ('spaghetti', 'milk') ---> ('eggs',)|| confidence = 0.252  &  lift = 1.402
# ('eggs', 'milk') ---> ('chocolate',)|| confidence = 0.299  &  lift = 1.823
# ('eggs', 'chocolate') ---> ('milk',)|| confidence = 0.277  &  lift = 2.138
# ('milk', 'eggs') ---> ('chocolate',)|| confidence = 0.299  &  lift = 1.823
# ('milk', 'chocolate') ---> ('eggs',)|| confidence = 0.286  &  lift = 1.593
# ('chocolate', 'eggs') ---> ('milk',)|| confidence = 0.277  &  lift = 2.138
# ('chocolate', 'milk') ---> ('eggs',)|| confidence = 0.286  &  lift = 1.593
# ('eggs', 'french fries') ---> ('chocolate',)|| confidence = 0.231  &  lift = 1.408
# ('eggs', 'chocolate') ---> ('french fries',)|| confidence = 0.253  &  lift = 1.48
# ('french fries', 'eggs') ---> ('chocolate',)|| confidence = 0.231  &  lift = 1.408
# ('french fries', 'chocolate') ---> ('eggs',)|| confidence = 0.244  &  lift = 1.359
# ('chocolate', 'eggs') ---> ('french fries',)|| confidence = 0.253  &  lift = 1.48
# ('chocolate', 'french fries') ---> ('eggs',)|| confidence = 0.244  &  lift = 1.359
# ('eggs', 'spaghetti') ---> ('chocolate',)|| confidence = 0.288  &  lift = 1.76
# ('eggs', 'chocolate') ---> ('spaghetti',)|| confidence = 0.317  &  lift = 1.822
# ('spaghetti', 'eggs') ---> ('chocolate',)|| confidence = 0.288  &  lift = 1.76
# ('spaghetti', 'chocolate') ---> ('eggs',)|| confidence = 0.269  &  lift = 1.495
# ('chocolate', 'eggs') ---> ('spaghetti',)|| confidence = 0.317  &  lift = 1.822
# ('chocolate', 'spaghetti') ---> ('eggs',)|| confidence = 0.269  &  lift = 1.495
# ('eggs', 'spaghetti') ---> ('ground beef',)|| confidence = 0.245  &  lift = 2.489
# ('eggs', 'ground beef') ---> ('spaghetti',)|| confidence = 0.447  &  lift = 2.565
# ('spaghetti', 'eggs') ---> ('ground beef',)|| confidence = 0.245  &  lift = 2.489
# ('spaghetti', 'ground beef') ---> ('eggs',)|| confidence = 0.228  &  lift = 1.268
# ('ground beef', 'eggs') ---> ('spaghetti',)|| confidence = 0.447  &  lift = 2.565
# ('ground beef', 'spaghetti') ---> ('eggs',)|| confidence = 0.228  &  lift = 1.268
# ('milk', 'frozen vegetables') ---> ('spaghetti',)|| confidence = 0.35  &  lift = 2.012
# ('milk', 'spaghetti') ---> ('frozen vegetables',)|| confidence = 0.233  &  lift = 2.445
# ('frozen vegetables', 'milk') ---> ('spaghetti',)|| confidence = 0.35  &  lift = 2.012
# ('frozen vegetables', 'spaghetti') ---> ('milk',)|| confidence = 0.297  &  lift = 2.289
# ('spaghetti', 'milk') ---> ('frozen vegetables',)|| confidence = 0.233  &  lift = 2.445
# ('spaghetti', 'frozen vegetables') ---> ('milk',)|| confidence = 0.297  &  lift = 2.289
# ('milk', 'spaghetti') ---> ('chocolate',)|| confidence = 0.308  &  lift = 1.881
# ('milk', 'chocolate') ---> ('spaghetti',)|| confidence = 0.34  &  lift = 1.954
# ('spaghetti', 'milk') ---> ('chocolate',)|| confidence = 0.308  &  lift = 1.881
# ('spaghetti', 'chocolate') ---> ('milk',)|| confidence = 0.279  &  lift = 2.152
# ('chocolate', 'milk') ---> ('spaghetti',)|| confidence = 0.34  &  lift = 1.954
# ('chocolate', 'spaghetti') ---> ('milk',)|| confidence = 0.279  &  lift = 2.152
# ('milk', 'spaghetti') ---> ('ground beef',)|| confidence = 0.274  &  lift = 2.793
# ('milk', 'ground beef') ---> ('spaghetti',)|| confidence = 0.442  &  lift = 2.541
# ('spaghetti', 'milk') ---> ('ground beef',)|| confidence = 0.274  &  lift = 2.793
# ('spaghetti', 'ground beef') ---> ('milk',)|| confidence = 0.248  &  lift = 1.916
# ('ground beef', 'milk') ---> ('spaghetti',)|| confidence = 0.442  &  lift = 2.541
# ('ground beef', 'spaghetti') ---> ('milk',)|| confidence = 0.248  &  lift = 1.916
# ('frozen vegetables', 'spaghetti') ---> ('ground beef',)|| confidence = 0.311  &  lift = 3.165
# ('frozen vegetables', 'ground beef') ---> ('spaghetti',)|| confidence = 0.512  &  lift = 2.94
# ('spaghetti', 'frozen vegetables') ---> ('ground beef',)|| confidence = 0.311  &  lift = 3.165
# ('spaghetti', 'ground beef') ---> ('frozen vegetables',)|| confidence = 0.221  &  lift = 2.319
# ('ground beef', 'frozen vegetables') ---> ('spaghetti',)|| confidence = 0.512  &  lift = 2.94
# ('ground beef', 'spaghetti') ---> ('frozen vegetables',)|| confidence = 0.221  &  lift = 2.319
# ('spaghetti', 'chocolate') ---> ('ground beef',)|| confidence = 0.235  &  lift = 2.389
# ('spaghetti', 'ground beef') ---> ('chocolate',)|| confidence = 0.235  &  lift = 1.432
# ('chocolate', 'spaghetti') ---> ('ground beef',)|| confidence = 0.235  &  lift = 2.389
# ('chocolate', 'ground beef') ---> ('spaghetti',)|| confidence = 0.399  &  lift = 2.291
# ('ground beef', 'spaghetti') ---> ('chocolate',)|| confidence = 0.235  &  lift = 1.432
# ('ground beef', 'chocolate') ---> ('spaghetti',)|| confidence = 0.399  &  lift = 2.291
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# strong assossiation_rules :
# ('herb & pepper',) ---> ('ground beef',)|| confidence = 0.323  &  lift = 3.292
# ('frozen vegetables', 'spaghetti') ---> ('ground beef',)|| confidence = 0.311  &  lift = 3.165
# ('spaghetti', 'frozen vegetables') ---> ('ground beef',)|| confidence = 0.311  &  lift = 3.165

# %%
print("requirements : ")
print(pd.__version__)
print(np.__version__)
# Out:
# requirements :
# 2.2.1
# 1.23.5
